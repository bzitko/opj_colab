# %%
import re
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
from porter import PorterStemmer

# %% [markdown]
# ## 8.1 Učitavanje stop riječi i postavljanje stemera
#
# Stop riječi se nalaze u datoteci `stopwords.txt`. One se učitaju i skup stop riječi se postave u varijablu `STOPWORDS`.
# Stemer je klasa `PorterStemmer` koja se nalazi u modulu `porter.py`.
# Ova klasa ima metodu `stem()`koja prima riječ i vraća korijen te riječi. Metoda `stem()` se postavi u variajablu `STEM`.

# %%
STOPWORDS = set(open("stopwords.txt").read().split())

print("STOP riječi...")
print(STOPWORDS)
print()


STEM = PorterStemmer().stem
print("STEM primjer...")
for w in STOPWORDS:
    s = STEM(w)
    if w != s:
        print(w, "->", s)
# Out:
# STOP riječi...
# {'t', 'against', 'when', 'his', 'do', 'nor', 'y', 'it', "you'll", 'from', 'few', 'we', 'off', 'i', 'with', 'more', "shouldn't", 'after', 've', 'theirs', 'you', 'their', 'each', 'such', "won't", 'has', 'both', 'her', 'ourselves', 'were', 'over', 'any', 'him', 'to', 'those', 'then', "mightn't", 'our', 'hasn', 'didn', 'not', 'being', "you're", 'for', 'further', 'into', 'was', 'under', 'are', 'she', 'why', 'be', 'hers', 'ma', 'o', "that'll", 'this', 'your', 'yours', "you've", 'the', 'just', 'down', "needn't", 'mightn', 'm', 'no', 'doesn', 'here', 'same', 'haven', 'while', 'out', 'most', "shan't", 'doing', 'as', 'but', 'between', "weren't", 'itself', 'ours', 'through', 'up', 'some', "hadn't", "isn't", 'who', 'd', 'have', 'than', 'and', "it's", 'mustn', 'what', 'isn', 're', 'ain', 'own', 'because', 'herself', 'themselves', 'or', 'whom', 'its', "doesn't", 'weren', "aren't", "wasn't", "haven't", 'shan', 'couldn', 'now', 'a', 'should', 'too', 'until', 'don', 'is', 'during', "couldn't", 'won', 'will', 'all', 'my', 'again', 'they', 'that', 'if', 'does', "hasn't", 'yourself', 'once', 'aren', 'about', 'wasn', "didn't", 'these', 'he', 'been', 'how', 'other', 's', "you'd", 'before', 'at', 'them', 'hadn', 'myself', 'me', "don't", 'll', 'very', "she's", 'where', 'of', "should've", 'having', 'by', 'in', 'so', "wouldn't", 'which', 'below', 'did', 'can', 'shouldn', 'himself', 'on', "mustn't", 'yourselves', 'am', 'above', 'wouldn', 'an', 'only', 'there', 'had', 'needn'}
#
# STEM primjer...
# his -> hi
# theirs -> their
# has -> ha
# ourselves -> ourselv
# any -> ani
# being -> be
# you're -> you'r
# was -> wa
# why -> whi
# hers -> her
# this -> thi
# yours -> your
# you've -> you'v
# doing -> do
# ours -> our
# it's -> it'
# because -> becaus
# themselves -> themselv
# its -> it
# during -> dure
# does -> doe
# once -> onc
# before -> befor
# very -> veri
# she's -> she'
# should've -> should'v
# having -> have
# yourselves -> yourselv
# above -> abov
# only -> onli

# %% [markdown]
# ## 8.2. Učitavanje podataka
#
# U datotekama `tweets_positive.txt` i `tweets_negative.txt` se u svakom redu nalazi po jedan pozitivan, odnosno negativan tweet. Nakon učitavanja tweetova u varijablama `positive_tweets` i `negative_tweets` slijedi njihova podjela na tweetove za treniranje i testiranje u omjeru 80:20.
#
# Na kraju, varijable `train` i `test` sadrže parove oblika `(tweet, 1)` ako je sentimenta tweeta pozitivan i `(tweet, 0)` ako je sentiment tweeta negativan.
#
# Radi tabličnog prikaza podataka, korišten je `pandas` modul i njegova klasa `DataFrame` koja može primiti listu podataka `data` i nazive stupaca `columns`.

# %%
positive_tweets = open('tweets_positive.txt').read().split("\n")
negative_tweets = open('tweets_negative.txt').read().split("\n")
print("Broj pozitivnih tweetova:", len(positive_tweets))
print("Broj negativnih tweetova:", len(positive_tweets))

n_positive, n_negative = len(positive_tweets) * 80 // 100, len(negative_tweets) * 80 // 100

train_pos, test_pos = positive_tweets[:n_positive], positive_tweets[n_positive:]
train_neg, test_neg = negative_tweets[:n_negative], negative_tweets[n_negative:]

train = [(tweet, 1) for tweet in train_pos] + [(tweet, 0) for tweet in train_neg]
test = [(tweet, 1) for tweet in test_pos] + [(tweet, 0) for tweet in test_neg]

print("Broj tweetova za treniranje", len(train))
print("Broj tweetova za testiranje", len(test))

pd.DataFrame(data=train, columns=["tweet", "sentiment"])
# Out:
# Broj pozitivnih tweetova: 5000
# Broj negativnih tweetova: 5000
# Broj tweetova za treniranje 8000
# Broj tweetova za testiranje 2000
#                                                   tweet  sentiment
# 0     #FollowFriday @France_Inte @PKuchly57 @Milipol...          1
# 1     @Lamb2ja Hey James! How odd :/ Please call our...          1
# 2     @DespiteOfficial we had a listen last night :)...          1
# 3                                  @97sides CONGRATS :)          1
# 4     yeaaaah yippppy!!!  my accnt verified rqst has...          1
# ...                                                 ...        ...
# 7995                   Amelia didnt stalk my twitter :(          0
# 7996                    oh, i missed the broadcast. : (          0
# 7997  i really can't stream on melon i feel useless :-(          0
# 7998   I need to stop looking at old soccer pictures :(          0
# 7999  Got an interview for the job that I want but t...          0
#
# [8000 rows x 2 columns]

# %% [markdown]
# ## 8.3 Predobrada teksta
#
# Svaki tweet će se
# * pretvoriti u male znakove
#
# i zatim će se uz pomoć regularnih izraza
# * izbacit će se hiperveze
# * izbacit će se html oznake kao &amp; i sl.,
# * izbacit će se nazivi korisnika oblika `@user` i hash tagovi oblika `#tag`
# * odvojit će se interpunkcije na početku i na kraju tokena
#
# zatim će se razbiti na riječi i izbaciti stop riječi, te će se provesti stemanje svake riječi.
# Za rezultat se dobije lista riječi.
#
# Zatim će se uz pomoć `pandas.DataFrame` prikazati nekoliko pozitivnih i negativnih tweetova prije i poslije obrade.

# %%
def text_process(txt):
    txt = txt.lower()
    txt = re.sub(r'https?://.*', '', txt)
    txt = re.sub(r"&\S+;", "", txt)
    txt = re.sub(r'[@#]\S+', '', txt)
    txt = re.sub(r"(\W*)(\w*)(\W+)", r"\1 \2 \3", txt)

    words = [word for word in txt.split() if word not in STOPWORDS]
    words = [STEM(w) for w in words]
    return words

pd.DataFrame([(1, doc, text_process(doc)) for doc in positive_tweets[:5]] + 
             [(0, doc, text_process(doc)) for doc in negative_tweets[:5]] , columns=["Sentiment", "Tweet", "Processed"])
# Out:
#    Sentiment                                              Tweet  \
# 0          1  #FollowFriday @France_Inte @PKuchly57 @Milipol...
# 1          1  @Lamb2ja Hey James! How odd :/ Please call our...
# 2          1  @DespiteOfficial we had a listen last night :)...
# 3          1                               @97sides CONGRATS :)
# 4          1  yeaaaah yippppy!!!  my accnt verified rqst has...
# 5          0                                hopeless for tmr :(
# 6          0  Everything in the kids section of IKEA is so c...
# 7          0  @Hegelbon That heart sliding into the waste ba...
# 8          0  “@ketchBurning: I hate Japanese call him "bani...
# 9          0           Dang starting next week I have "work" :(
#
#                                            Processed
# 0             [top, engag, member, commun, week, :)]
# 1  [hey, jame, !, odd, :/, pleas, call, contact, ...
# 2  [listen, last, night, :), bleed, amaz, track, ...
# 3                                      [congrat, :)]
# 4  [yeaaaah, yippppi, !!!, accnt, verifi, rqst, s...
# 5                                [hopeless, tmr, :(]
# 6  [everyth, kid, section, ikea, cute, ., shame, ...
# 7                [heart, slide, wast, basket, ., :(]
# 8      [“, hate, japanes, call, ", bani, ", :(, :(”]
# 9          [dang, start, next, week, ", work, ", :(]

# %% [markdown]
# ## 8.4 Prebrojavanje pozitivnih i negativnih riječi
#
# U rječniku `FREQS` će se za svaki ključ oblika (riječ, sentiment) čuvati broj pojavljivanja te riječi u tweetovima istog sentimenta. Zatim se uz pomoć `pandas.DataFrame` prikazuje nekoliko najfrekventnijih riječi.

# %%
def make_freqs(tweets):
    freqs = {}
    for tweet, sentiment in tweets:
        words = text_process(tweet)
        for w in words:
            w = STEM(w)
            freqs[w, sentiment] = freqs.get((w, sentiment), 0) + 1
    return freqs

FREQS = make_freqs(train + test)

data = [(w, s, FREQS[w, s]) for w, s in sorted(FREQS, key=FREQS.get, reverse=True)]

# pd.set_option('display.min_rows', 40)
pd.DataFrame(data, columns=["word", "sentiment", "frequency"])
# Out:
#          word  sentiment  frequency
# 0          :(          0       3830
# 1          :)          1       3155
# 2           '          0       1736
# 3           '          1       1281
# 4           .          1       1230
# ...       ...        ...        ...
# 12300  jaebum          0          1
# 12301   ahmad          0          1
# 12302  maslan          0          1
# 12303    hull          0          1
# 12304  misser          0          1
#
# [12305 rows x 3 columns]

# %% [markdown]
# ## 8.5. Izvlačenje osobina
#
# Funkcija `features_extraction()` prima tekst tweeta kojeg pretvara u vektor osobina oblika
#
# `[broj pozitivnih riječi, broj negativnih riječi, 1]`
#
# Broj 1 je, radi jednostavnosti, stavljen na kraju jer će se on množiti s pristranošću `b`.

# %%
def features_extraction(txt):
    words = text_process(txt)
    x = np.array([0, 0, 1])
    for word in words:
        x[0] += FREQS.get((word, 1), 0)
        x[1] += FREQS.get((word, 0), 0)

    assert x.shape == (3,)
    return x

tweet = train[0][0]
x = features_extraction(tweet)

print(tweet)
print(x)
# Out:
# #FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)
# [3326   71    1]

# %% [markdown]
# Sada možemo tweetove prikazati u koordinatnom sustavu.
# Koordinata x će biti broj pozitivnih riječi u tweetu, odnosno y će biti broj negativnih riječi u tweetu.

# %%
posx, posy = [], []
negx, negy = [], []
for tweet, sentiment in train + test:
    x, y, _ = features_extraction(tweet)
    if sentiment == 1:
        posx.append(x)
        posy.append(y)
    else:
        negx.append(x)
        negy.append(y)
    
plt.scatter(posx, posy, color="green", marker=".", label="positive")
plt.scatter(negx, negy, color="red", marker=".", label="negative")
plt.legend()

# %% [markdown]
# ## 8.6. Učenje opadanjem gradijenta
#
# Sada se može pristupiti učenju koje se provodi nad podacima za treniranje. Prvo je definira aktivacijska funkcija `sigmoid()`.

# %%
def sigmoid(x): 
    return 1 / (1 + np.exp(-x))

x = np.arange(-10, 10, 0.1)
plt.plot(x, sigmoid(x))

# %% [markdown]
# Zatim je definirana funkcija opadanja gradijenta `gradient_descent()` koja ima sljedeće parametre:
# * x - m vektora oblika $[x_1, x_2, 1]$ kojima je predstavljen tweet
# * y - m skalara gdje 1 predstavlja pozitivan sentiment, a 0 negativan sentiment
# * alpha - rata učenja
# * num_iters - broj iteracija
#
# Izlaz ove funkcije je
# * `loss`- lista gubitaka kod svake iteracije
# * `theta` - naučeni parametri modela, odnosno u ovom slučaju $\Theta = [w_1, w_2, b]$
#
# Koraci algoritma opadanja gradijenta su:
# * u `m` se postavi broj tweetova, a u `n` broj osobina svakog tweeta (u ovom slučaju, $n = 3$)
# * inicijalno se stvori `theta` ($\Theta = [0, 0, 0]$)
# * lista gubitaka `loss` je inicijalno prazna
# * za svaku iteraciju od `num_iters` iteracija:
#     * `z` je vektor koji sadrži skalarni produkt od `theta`i svakog vektora iz `x` ($\Theta \cdot x = w_1 x_1 + w_2 x_2 + b$)
#     * nad svakim dobivenim skalarom se primjeni aktivacijska funkcija `sigmoid()` ($\hat{y} = \sigma(\Theta \cdot x)$)
#     * izračuna se gubitak `J` i doda u listu `loss` ( $J= - \frac{1}{m} \sum{[y log(\hat{y}) + (1 - y)log(1-\hat{y})]}$ )
#     * izračuna se gradijent `grad` od `theta` ($\frac{\partial{\Theta}}{\partial{w_i}}=( \hat{y_i} - y_i) x_i $ )
#     * promijeni se `theta` temeljem rate učenja i gradijenta ( $\Theta = \Theta - \frac{\alpha}{m} \nabla \Theta$  )
# * vrati se `loss` i `theta`

# %%
def gradient_descent(x, y, alpha, num_iters):        
    m, n = x.shape
    theta = np.zeros(n)
    loss = []
    for i in range(0, num_iters):
        z = np.dot(theta, x.T)
        yh = sigmoid(z)
        assert z.shape == (m, )        
        assert yh.shape == (m, )

        J = -(1 / m) * (np.dot(y, np.log(yh)) + np.dot((1 - y), np.log(1 - yh))) 
        loss.append(J)
        grad = np.dot(x.T, yh - y)
        theta = theta - (alpha / m) * grad

    return loss, theta

# %% [markdown]
# Prvo se pripreme matrica `X` i vektor `Y`.
#
# Svaki redak matrice `X` je vektor osobina tweeta $[x_1, x_2, 1]$ dok je svaki skalar u vektoru `Y` ili 1 ili 0 ovisno o tome je li tweet pozitivan ili negativan. Parovi tweetova i pripadni sentiment se uzimaju iz `train`.
#
# Zatim se pokrene `gradient_descent()` za `X` i `Y` uz ratu učenja $\alpha = 10^{-8}$ i broj iteracija 1500.
# Nakon učenja se ispiše `theta` i nacrta se graf gubitka za svaku iteraciju.

# %%
train_x = np.array([features_extraction(tweet) for tweet, _ in train])
train_y = np.array([sentiment for _, sentiment in train])

loss, theta = gradient_descent(train_x, train_y, alpha=1e-8, num_iters=1500)
print("THETA: ", theta)

plt.plot(loss)
plt.xlabel("Iteration")
plt.ylabel("Loss")
# Out:
# THETA:  [ 1.33211828e-03 -1.22686183e-03  1.59567628e-07]
# Text(0, 0.5, 'Loss')

# %% [markdown]
# ## 8.7 Učenje stohastičkim opadanjem gradijenta
#
# Kod stohastičkog opadanja gradijenta potrebno je znati veličinu grupe `batch_size`. Temeljem ovog parametra određuje se broj slučajno odabranih vektora iz `x` i `y` kod svake iteracije.
#
# Nad takvim vektorima se u nastavku iteracije provode koraci kao i kod opadanja gradijenta.

# %%
def stohastic_gradient_descent(x, y, alpha, num_iters, batch_size):
    m, n = x.shape
    theta = np.zeros(n)
    loss = []
    for i in range(0, num_iters):
        row_is = np.random.choice(m, size=batch_size, replace=False)
        batch_x = x[row_is, :]
        batch_y = y[row_is]
        
        z = np.dot(theta, batch_x.T)
        batch_yh = sigmoid(z)
        J = -(1 / batch_size) * (np.dot(batch_y, np.log(batch_yh)) + np.dot((1 - batch_y), np.log(1 - batch_yh)))     
        loss.append(J)        
        theta = theta - (alpha / batch_size) * np.dot(batch_x.T, batch_yh - batch_y)

    return loss, theta

# %% [markdown]
# Osim rate učenja $\alpha$ i broja iteracija 1500, postavlja se parametar `batch_size`

# %%
loss, theta = stohastic_gradient_descent(train_x, train_y, alpha=1e-8, num_iters=1500, batch_size=1024)

print("THETA: ", theta)

plt.plot(loss)
plt.xlabel("Iteration")
plt.ylabel("Loss")
# Out:
# THETA:  [ 1.33008220e-03 -1.22874541e-03  1.57237841e-07]
# Text(0, 0.5, 'Loss')

# %% [markdown]
# ## 8.8 Evaluacija
#
# Sada za svaki tweet možemo predviditi sentiment. Stoga je definirana funkcija `predict()` koja će za dani `tweet` i model `theta` odrediti broj iz segmenta $[0, 1]$. Ako je broj bliže 0, onda smatramo da je sentiment 0, odnosno negativan. Međutim, ako je broj bliže 1, onda se radi o pozitivnom sentimentu.

# %%
def predict(tweet, theta):
    x = features_extraction(tweet)
    y_pred = sigmoid(np.dot(x, theta))
    return y_pred

pd.DataFrame(data=[(tweet, sentiment, predict(tweet, theta)) for tweet, sentiment in test],
             columns=["tweet", "sentiment", "prediction"])
# Out:
#                                                   tweet  sentiment  prediction
# 0     Bro:U wan cut hair anot,ur hair long Liao bo M...          1    0.997924
# 1     @heyclaireee is back! thnx God!!! i'm so happy :)          1    0.994142
# 2     @BBCRadio3 thought it was my ears which were m...          1    0.885678
# 3     @HumayAG 'Stuck in the centre right with you. ...          1    0.987678
# 4               Happy Friday :-) http://t.co/iymPIlWXFY          1    0.767505
# ...                                                 ...        ...         ...
# 1995               I wanna change my avi but uSanele :(          0    0.008263
# 1996                         MY PUPPY BROKE HER FOOT :(          0    0.008822
# 1997           where's all the jaebum baby pictures :((          0    0.307496
# 1998  But but Mr Ahmad Maslan cooks too :( https://t...          0    0.008924
# 1999  @eawoman As a Hull supporter I am expecting a ...          0    0.383208
#
# [2000 rows x 3 columns]

# %% [markdown]
# Temeljem testnih podataka se izvuku vektori `test_x`i `test_y` slično kako su se odredili `train_x` i `train_y` za treniranje.
#
# Evaluacija započinje izradom tablice zabune temeljem podataka za testiranje. Funkcija `test_contingency()` prima:
# * `x` vektore tweetova,
# * `y` njihove točne sentimente `y` i
# * `theta` naučeni model.
#
# Za izlaz od `test_contingency()` se dobiva - po redu:
# * `tp` - broj stvarno pozitivnih tweetova,
# * `fp` - broj lažno pozitivnih tweetova,
# * `fn` - broj lažno negativnih tweetova i
# * `tn` - broj istinito negativnih tweetova.
#
# Funkcija `test_evaluate()` za dobivenu tablicu zabune `tp`, `fp`, `fn` i `tn` se određuje - po redu:
# * `acc` - točnost,
# * `p` - preciznost,
# * `o` - odziv,
# * `f1` - F1 mjera.

# %%
test_X = np.array([features_extraction(tweet) for tweet, _ in test])
test_Y = np.array([sentiment for _, sentiment in test])

def test_contingency(x, y, theta):
    fx =  sigmoid(np.dot(theta, x.T))
    assert fx.shape == y.shape
    yh = np.array([1 if z > 0.5 else 0 for z in fx])

    tp = fp = fn = tn = 0
    for yi, yhi in zip(y, yh):
        if yhi == 1:
            if yi == 1:
                tp += 1
            else:
                fp += 1
        else:
            if yi == 1:
                fn += 1
            else:
                tn += 1

    return tp, fp, fn, tn

def test_evaluate(tp, fp, fn, tn):
    a = (tp + tn) / (tp + fp + fn + tn)
    p = tp / (tp + fp)
    r = tp / (tp + fn)
    f1 = 2 * p * r / (p + r)
    
    return a, p, r, f1
    

test_x = np.array([features_extraction(tweet) for tweet, _ in test])
test_y = np.array([sentiment for _, sentiment in test])

tp, fp, fn, tn = test_contingency(test_x, test_y, theta)
a, p, r, f1 = test_evaluate(tp, fp, fn, tn)

print("TP: ", tp) 
print("FP: ", fp) 
print("FN: ", fn) 
print("TN: ", tn) 
print() 
print(f"Accuracy   : {a:.4f}")
print(f"Precission : {p:.4f}")
print(f"Recall     : {r:.4f}")
print(f"F1         : {f1:.4f}")
# Out:
# TP:  969
# FP:  44
# FN:  31
# TN:  956
#
# Accuracy   : 0.9625
# Precission : 0.9566
# Recall     : 0.9690
# F1         : 0.9627

# %% [markdown]
# ## 8.9. Greške
#
# Na poslijetku, mogu se pregledati tweetovi kojima model nije dobro predvidio sentiment. Analizom takvih tweetova je moguće odrediti dodatne osobine ili promjeniti postojeće osobine opisane u funkciji `features_extraction()`.
#
# Funkcija `test_errors()` prima:
# * `x` vektore tweetova,
# * `y` njihove točne sentimente `y` i
# * `theta` naučeni model.
#
# a vraća `pd.DataFrame` tablicu sa stupcima:
# * i - broj pozicije tweeta i sentimenta,
# * Tweet - tekst tweeta
# * Processed - predobrađeni tekst tweeta u obliku liste pojavnica.
# * Predict - rezultat predviđanja,
# * Sentiment - stvarni sentiment,
# * Error - vrsta greške, koja može biti lažno pozitivna ili lažno negativna.

# %%
def test_errors(x, y, theta):
    data = []
    fx =  sigmoid(np.dot(theta, x.T))
    yh = np.array([1 if z > 0.5 else 0 for z in fx])
    for i, (yi, yhi) in enumerate(zip(y, yh)):
        if yi != yhi:
            tweet, sentiment = test[i]
            data.append((i, tweet, text_process(tweet), predict(tweet, theta), yi, "False positive" if yhi == 1 else "False negative"))
    return pd.DataFrame(data, columns=["i", "Tweet", "Processed", "Predict", "Sentiment", "Error"])

pd.set_option('display.max_rows', 100)

test_errors(test_x, test_y, theta).sort_values(by="Predict")
# Out:
#        i                                              Tweet  \
# 8    155  Movie 'Key of Life' (Japanese Version) https:/...
# 7    151  @Clareyh Yeah, it's a classy look :-). I've se...
# 6    148  It's not like it hurt my feelings or anything ...
# 20   521  Ok good night I wish troye wasn't ugly and I m...
# 30   985                            Who's still awake ?:)))
# 13   225  @heyoppar @Zain9898 @bemybelief @hetthuocchua ...
# 1     31  That awkward moment when your name is 'Akarsha...
# 16   315  @wontanim yep we're all trash af   im from ind...
# 11   199  @storpey don't die, you're actually pretty ent...
# 27   736  @PXC_Macavity In case you didn't.. it's on my ...
# 19   485             At least there's one cool thing :-))))
# 2     32              @Ms_chic I know :), you're hot always
# 10   194  @SasaRichardson @Stefbystef_ @Frgt10_Anthem so...
# 25   671                         @el_crd2601  la class's :p
# 18   416  @wildrunnerza @ctmarathon @runnersworldza One ...
# 14   283          @javeedna that's a build up for Sunday :p
# 4    125  Hi,i'm definetly so exited ^^ I'm going to New...
# 24   669  @BrandonHerrigan Welcome :), when's your next ...
# 28   822             @msarosh Uff Itna Miss karhy thy ap :p
# 5    127  @babypuffinator i've typed worse things, it's ...
# 29   881              @SwgGuy Hah.... :D Don't say sorry...
# 3     54              I :)"@Kreizi_: Who wants a #FF S/O??"
# 17   361  @supersarcastiel #BlueSidemenXIX I'd love to w...
# 9    167  Whatsapp with roommate  "Do you want anything ...
# 12   204  @mariaburtea @5SOS_Nightly wow you really hate...
# 0     22    @mommydean74 @Patriotic_Me Delighted, m'dear!:)
# 26   711              getting home at 4 waking up at 9 :):)
# 23   662  I'm that person that has to workout and eat he...
# 21   526  @greatestcookie It hurts having to read about ...
# 15   293                 and I have to be up for 7 :):):):)
# 22   639  If u like uta read the manga :-))) you'll love...
# 58  1628  Again, I would just want people to understand ...
# 33  1104  😂😂 what a night :(((((( so devo xxx https://t....
# 66  1738                              worried :-(((((((((((
# 61  1657          @jhapaliMailo , some people :(( How r  u?
# 43  1352                       My last day in Indiana :((((
# 44  1364  @bumkeyyfel b-butt : ( isn't black cat a bad l...
# 36  1182   Srsly, Y U do that? :((  https://t.co/g0r01GGj2b
# 62  1663      Waiting for love me recuerda tanto a Bath :((
# 35  1114          @ssulstagram why you unfollow me unnie?:(
# 64  1709  When fave unfollows :(😩💖 @itisfurny http://t.c...
# 57  1610  😢 "@ haestarr: i’m just :(( http://t.co/FY8LWo...
# 56  1576                                      Bad day???:-(
# 46  1414  @iperfectyonce @justinbieber its my biggest dr...
# 55  1560                       !! NUGGETS AND FRIES !! :-((
# 74  1947  Last day on the beach :-(:-(:-(.... http://t.c...
# 67  1754                      FOLLOW ME PLS!:( @tommophoebe
# 45  1392  MY FAV EMOTICON RIGHT NOW IS THE " :(: " EMOTICON
# 48  1475  Need a small lady to walk over my back. So sor...
# 50  1501  Hammering down here right now......looks set f...
# 51  1514  @BRATSUNITED @ShutUpPenguin @epiphanichood why...
# 72  1858                             Overly attached. :((((
# 38  1211        but srsly tho, bae looks so out of it :((((
# 49  1483  @fyoudontknow WAIT ITS GONE. LITERALLY IT IS :...
# 34  1112  Dadas uh iphone na, :(:( [pic] — https://t.co/...
# 37  1196  @1994sdork omg :-(( I LOVE YOU SO MUCH MONICA ...
# 53  1526  @carterreynolds @hankgreen because you're asia...
# 42  1343  @yuniizu LA time, right? Yes yunnie, im seriou...
# 65  1715            the internet is being a total bitch : (
# 68  1756  my beloved grandmother : ( https://t.co/wt4oXq...
# 54  1544                                       pats jay : (
# 39  1298  @phenomyoutube u probs had more fun with david...
# 73  1937  I need to like, tell myself na, na okay lang :...
# 31  1025  one of my friend is following me , a little he...
# 52  1515  @FreedomChild3 Had wondered why this has not h...
# 59  1636  😂😂😂thank you San😀"@__Zanele: I wanna change my...
# 32  1040  @ryannhough I can imagine! This would shatter ...
# 70  1773  @CHEDA_KHAN Thats life. I get calls from peopl...
# 63  1690                    @Velocentric Slow news day! :-(
# 71  1853  Sr. Financial Analyst - Expedia, Inc.: (#Belle...
# 40  1314  @JayMcGuiness happy birthday again! And please...
# 47  1462  My computer has broken and i have to wait unti...
# 60  1653  @exobab1es tzelumxoxo ! I dont really used lin...
# 69  1770  @The5BallOver @Radio702 :-( It's not a challen...
# 41  1322  This&gt;@AnaMyID a pathetic emotional burden.S...
#
#                                             Processed   Predict  Sentiment  \
# 8     [movi, ', key, life, ', (, japanes, version, )]  0.318070          1
# 7   [yeah, ,, ', classi, look, :-)., ', seen, peop...  0.356472          1
# 6   [', like, hurt, feel, anyth, right, ??, :)))))...  0.356631          1
# 20  [ok, good, night, wish, troy, ', ugli, met, to...  0.373760          1
# 30                            [', still, awak, ?:)))]  0.373918          1
# 13              [', gonna, anoth, one, final, :)))))]  0.386376          1
# 1   [awkward, moment, name, ', akarshan, ',, end, ...  0.392441          1
# 16   [yep, ', trash, af, im, indonesia, hbu, ?, :-))]  0.394906          1
# 11      [', die, ,, ', actual, pretti, entertain, :p]  0.395620          1
# 27            [case, ', .., ', facebook, wall, ., :p]  0.402247          1
# 19               [least, ', one, cool, thing, :-))))]  0.411180          1
# 2                          [know, :),, ', hot, alway]  0.412002          1
# 10           [sombrero, high, ??, okay, ', lost, :))]  0.419726          1
# 25                                 [la, class, ', :p]  0.423417          1
# 18         [one, ", ok, ', run, photo, ', moment, :d]  0.427119          1
# 14                             [', build, sunday, :p]  0.427396          1
# 4   [hi, ,, ', definetli, exit, ^^, ', go, new, yo...  0.430068          1
# 24                    [welcom, :),, ', next, meet, ?]  0.440907          1
# 28              [uff, itna, miss, karhi, thi, ap, :p]  0.448794          1
# 5              [', type, wors, thing, ,, ', good, :p]  0.454329          1
# 29                 [hah, ...., :, ', say, sorri, ...]  0.460800          1
# 3                                 [:)", want, /, ??"]  0.466825          1
# 17                           [', love, win, one, :)!]  0.472487          1
# 9   [whatsapp, roommat, ", want, anyth, pari, ?", ...  0.481739          1
# 12                         [wow, realli, hate, :))))]  0.483741          1
# 0                          [delight, ,, ', dear, !:)]  0.484131          1
# 26                      [get, home, 4, wake, 9, :):)]  0.486591          1
# 23  [', person, workout, eat, healthi, minut, ', g...  0.494152          1
# 21          [hurt, read, peopl, ', holiday, work, :d]  0.496154          1
# 15                                      [7, :):):):)]  0.499664          1
# 22  [u, like, uta, read, manga, :-))), ', love, ev...  0.499910          1
# 58  [,, would, want, peopl, understand, busi, ,, d...  0.500230          0
# 33                    [😂😂, night, :((((((, devo, xxx]  0.500798          0
# 66                             [worri, :-(((((((((((]  0.502914          0
# 61                           [,, peopl, :((, r, u, ?]  0.502938          0
# 43                        [last, day, indiana, :((((]  0.508087          0
# 44  [b, -, butt, :, (, ', black, cat, bad, luck, ene]  0.508855          0
# 36                              [srsli, ,, u, ?, :((]  0.508995          0
# 62           [wait, love, recuerda, tanto, bath, :((]  0.510113          0
# 35                              [unfollow, unni, ?:(]  0.511756          0
# 64                             [fave, unfollow, :(😩💖]  0.517638          0
# 57                       [😢, "@, haestarr, :, ’, :((]  0.519517          0
# 56                                 [bad, day, ???:-(]  0.521471          0
# 46          [biggest, dream, u, follow, brooo, :((((]  0.523278          0
# 55                        [!!, nugget, fri, !!, :-((]  0.525127          0
# 74                  [last, day, beach, :-(:-(:-(....]  0.529989          0
# 67                                  [follow, pl, !:(]  0.530910          0
# 45        [fav, emoticon, right, ", :(:, ", emoticon]  0.532806          0
# 48  [need, small, ladi, walk, back, ., sore, ....,...  0.543682          0
# 50   [hammer, right, ......, look, set, day, .....:(]  0.550497          0
# 51  [?, lmao, ., back, get, realli, realli, seriou...  0.551934          0
# 72                         [overli, attach, ., :((((]  0.556138          0
# 38                  [srsli, tho, ,, bae, look, :((((]  0.564657          0
# 49                     [wait, gone, ., liter, :(((((]  0.566882          0
# 34       [dada, uh, iphon, na, ,, :(:(, [, pic, ], —]  0.576915          0
# 37  [omg, :-((, love, much, monica, see, soon, aaa...  0.578047          0
# 53  [', asian, !!!!, ummmm, mayb, ur, film, child,...  0.580442          0
# 42  [la, time, ,, right, ?, ye, yunni, ,, im, seri...  0.597389          0
# 65                     [internet, total, bitch, :, (]  0.598681          0
# 68                           [belov, grandmoth, :, (]  0.602762          0
# 54                                   [pat, jay, :, (]  0.603423          0
# 39                        [u, prob, fun, david, :, (]  0.613024          0
# 73  [need, like, ,, tell, na, ,, na, okay, lang, :...  0.624866          0
# 31  [one, friend, follow, ,, littl, heart, attack,...  0.627883          0
# 52  [wonder, happen, earlier, ?, realiz, ,, ', lea...  0.635817          0
# 59  [😂😂😂, thank, san, 😀", wanna, chang, avi, usane...  0.645852          0
# 32  [imagin, !, would, shatter, dream, :-(, ', let...  0.650319          0
# 70  [that, life, ., get, call, peopl, havent, seen...  0.675440          0
# 63                          [slow, news, day, !, :-(]  0.680615          0
# 71  [sr, ., financi, analyst, -, expedia, ,, inc, ...  0.686126          0
# 40  [happi, birthday, !, pleas, come, back, singap...  0.705698          0
# 47  [comput, broken, wait, fix, ., miss, much, twi...  0.718747          0
# 60  [tzelumxoxo, !, dont, realli, use, line, ipod,...  0.737176          0
# 69  [:-(, ', challeng, though, ., pleas, check, fb...  0.819183          0
# 41  [pathet, emot, burden, ., say, like, ,, care, ...  0.966442          0
#
#              Error
# 8   False negative
# 7   False negative
# 6   False negative
# 20  False negative
# 30  False negative
# 13  False negative
# 1   False negative
# 16  False negative
# 11  False negative
# 27  False negative
# 19  False negative
# 2   False negative
# 10  False negative
# 25  False negative
# 18  False negative
# 14  False negative
# 4   False negative
# 24  False negative
# 28  False negative
# 5   False negative
# 29  False negative
# 3   False negative
# 17  False negative
# 9   False negative
# 12  False negative
# 0   False negative
# 26  False negative
# 23  False negative
# 21  False negative
# 15  False negative
# 22  False negative
# 58  False positive
# 33  False positive
# 66  False positive
# 61  False positive
# 43  False positive
# 44  False positive
# 36  False positive
# 62  False positive
# 35  False positive
# 64  False positive
# 57  False positive
# 56  False positive
# 46  False positive
# 55  False positive
# 74  False positive
# 67  False positive
# 45  False positive
# 48  False positive
# 50  False positive
# 51  False positive
# 72  False positive
# 38  False positive
# 49  False positive
# 34  False positive
# 37  False positive
# 53  False positive
# 42  False positive
# 65  False positive
# 68  False positive
# 54  False positive
# 39  False positive
# 73  False positive
# 31  False positive
# 52  False positive
# 59  False positive
# 32  False positive
# 70  False positive
# 63  False positive
# 71  False positive
# 40  False positive
# 47  False positive
# 60  False positive
# 69  False positive
# 41  False positive
